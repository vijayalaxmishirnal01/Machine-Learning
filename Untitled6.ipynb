# %%
s="12345"*5
str="12345"
print (str[3: :5])
# Out:
# 4

# %%
str="concatenation"
substr=input ("Enter the no")
for i in range(0,len(str)):
 if str[i:i+3]=='cat':
   print ("cat is found")

# %%
s,t = raw_input().strip().split(' ')
s,t = [int(s),int(t)]
a,b = raw_input().strip().split(' ')
a,b = [int(a),int(b)]
m,n = raw_input().strip().split(' ')
m,n = [int(m),int(n)]
apple = map(int,raw_input().strip().split(' '))
orange = map(int,raw_input().strip().split(' '))
acount=0
for i in apple:
    if s<=a+i<=t:
        acount+=1

ocount=0
for i in orange:
    if s<=b+i<=t:
        ocount+=1

print('acount')
print('ocount')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-dd41fce3f7aa> in <module>()
# ----> 1 s,t = raw_input().strip().split(' ')
#       2 s,t = [int(s),int(t)]
#       3 a,b = raw_input().strip().split(' ')
#       4 a,b = [int(a),int(b)]
#       5 m,n = raw_input().strip().split(' ')
#
# NameError: name 'raw_input' is not defined

# %%
f=list(map(int,input().split (" ")))
s=int(input ("Enter the start position of Sam house:"))
t=int(input ("Enter the end point of Sam's house:"))
a=int(input ("Enter position of apple tree:"))
b=int(input ("Enter position of orange tree:"))
ca=0
co=0
for i in range(1,f[0]+1):
   d=int(input ("Enter distance:"))
   if(a+d>s & a+d<=t):
      ca+=1
      if(b+d>s & b+d<=t):
         co+=1
print (ca)
print (co)
# Out:
# 10 8
# Enter the start position of Sam house:5
# Enter the end point of Sam's house:8
# Enter position of apple tree:2
# Enter position of orange tree:12
# Enter distance:-4
# Enter distance:-3
# Enter distance:-2
# Enter distance:-1
# Enter distance:0
# Enter distance:4
# Enter distance:3
# Enter distance:2
# Enter distance:1
# Enter distance:4
# 4
# 4
