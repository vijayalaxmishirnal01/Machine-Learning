# %%
#1.Data Visualization using Scarp
import matplotlib.pyplot as plt
a=[2,4,5,6,7]
b=[7,8,9,10,11]
plt.title("Line Graph Visualization.")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.legend(loc=4)
plt.plot(a,b)
plt.show()
# Out:
# No handles with labels found to put in legend.
