# %%
#Scatter Graph
import matplotlib.pyplot as plt
a=[2,4,5,6,7]
b=[7,8,9,10,11]
plt.title("Scatter Graph Visualization.")
plt.xlabel("x axis")
plt.ylabel("y axis")
plt.scatter(a,b,color="blue",label="scatter plot",s=250,marker="*")
plt.legend(loc=2)
plt.scatter(a,b)
plt.show()
