# %%
import matplotlib.pyplot as plt
import pandas as pd
record={"Name":["Ajay","Arun","Amit"],"Age":[45,60,90]}
#df=pd.DataFrame(record)
#plt.plot(x="Name",y="Age",kind='Bar')
plt.pie(df["Age"], labels=df["Name"])
plt.show()
print("Line plots")
plt.plot(df["Age"],df["Name"])
plt.show()
print ("Scatter plots")
plt.scatter(df["Age"],df["Name"])
plt.show()
# Out:
# Line plots
# Scatter plots

# %%
import matplotlib.pyplot as plt
import pandas as pd
df=pd.DataFrame({
"x":[1,2,3,4,5],"y":[3,6,8,9,12]
})
plt.pie(df["x"], labels=df["y"])
plt.show()
print("Line plots")
plt.plot(df["x"],df["y"])
plt.show()
print ("Scatter plots")
plt.scatter(df["x"],df["y"])
plt.show()
# Out:
# Line plots
# Scatter plots

# %%
import pandas as pd
# importing matplotlib library
import matplotlib.pyplot as plt

# creating dataframe
df = pd.DataFrame({
 'X': [1, 2, 3, 4, 5],
 'Y': [2, 4, 6, 10, 15]
})

# plotting a line graph
print("Line graph:")
plt.plot(df["X"], df["Y"]) # pass the column names ( "Name" and "Feet")
plt.show()

# plotting a scatter plot
print("Scatter Plot: ")
plt.scatter(df["X"], df["Y"])
plt.show()
# Out:
# Line graph:
# Scatter Plot:

# %%
import pandas as pd
# importing matplotlib library
import matplotlib.pyplot as plt
df=pd.read_csv("/content/sample_data/DoBIH_v17_2.csv")
#df.head()
# plotting a line graph
print("Line graph:")
plt.plot(df["Name"], df["Feet"])
plt.show()

# plotting a scatter plot
print("Scatter Plot:")
plt.scatter(df["Name"], df["Feet"])
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (3,25) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Line graph:
# Scatter Plot:
